# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('Desktop/emplo_1.xlsx',header=1)

# %%
df = df.iloc[2: , :]

# %%
df.isnull().sum()
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 2      NaN      Valentine Parker           2022-06-23                   71.0
# 3        🚩     Gregoria Veum III           2022-06-23                   71.0
# 4      NaN     Isai Turcotte DVM           2022-06-23                   71.0
# 5      NaN          Alex Mueller           2022-06-23                   71.0
# 6      NaN            Coy Kuphal           2022-06-23                   71.0
# 7      NaN           Janis Bayer           2022-06-23                   71.0
# 8      NaN     Mr. Emelia Graham           2022-06-23                   71.0
# 9      NaN           Drake Hills           2022-06-23                   71.0
# 10     NaN         Kirk Mosciski           2022-06-23                   71.0
# 11     NaN         Verda Osinski           2022-06-23                   71.0
# 12     NaN     Lucius McCullough           2022-06-23                   71.0
# ...

# %%
df=df.reset_index(drop=True)

# %%
df=df.dropna(how='all')

# %%
df=df.drop_duplicates(keep='first')

# %%
df['Days since graduation']=df['Days since graduation'].astype(int)

# %%
df.loc[df['at risk'].isnull(),'at risk']='No'
df.loc[df['at risk']!='No','at risk']='Yes'

# %%
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0       No      Valentine Parker           2022-06-23                     71
# 1      Yes     Gregoria Veum III           2022-06-23                     71
# 2       No     Isai Turcotte DVM           2022-06-23                     71
# 3       No          Alex Mueller           2022-06-23                     71
# 4       No            Coy Kuphal           2022-06-23                     71
# 5       No           Janis Bayer           2022-06-23                     71
# 6       No     Mr. Emelia Graham           2022-06-23                     71
# 7       No           Drake Hills           2022-06-23                     71
# 8       No         Kirk Mosciski           2022-06-23                     71
# 9       No         Verda Osinski           2022-06-23                     71
# 10      No     Lucius McCullough           2022-06-23                     71
# ...

# %%
df['Career Week end date'].unique()
# Out:
# array(['2022-06-23T00:00:00.000000000', '2022-06-24T00:00:00.000000000',
#        '2022-06-27T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['Days since graduation'].unique()
# Out:
# array([71, 70, 67])

# %%
df['Outcome Category'].unique()
# Out:
# array(['Searching', 'Excluded', 'Employed'], dtype=object)

# %%
df['Outcome Status'].unique()
# Out:
# array(['Searching', 'Not Eligible', 'Hired In Field', 'Back To Job',
#        'Entrepreneur', 'Ironhack Employee',
#        'Not Graduated In Career Services'], dtype=object)

# %%
df['Track'].unique()
df.loc[df['Track'].isnull(),'Track']='Other'
df.columns
# Out:
# Index(['at risk', 'Name', 'Career Week end date', 'Days since graduation',
#        'Cohort Name', 'Outcome Category', 'Outcome Status', 'Track', 'Format',
#        'Campus', 'CV', 'Linkedin', 'Portfolio', 'Job ready pct',
#        'Soft skills score', 'Soft skills pct', 'Assessment score', 'Lab score',
#        'Final project grade', 'Final project pct'],
#       dtype='object')

# %%
for col in df.columns:
    df.loc[df[col]==" ",col]=np.nan
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0       No      Valentine Parker           2022-06-23                   71.0
# 1      Yes     Gregoria Veum III           2022-06-23                   71.0
# 2       No     Isai Turcotte DVM           2022-06-23                   71.0
# 3       No          Alex Mueller           2022-06-23                   71.0
# 4       No            Coy Kuphal           2022-06-23                   71.0
# 5       No           Janis Bayer           2022-06-23                   71.0
# 6       No     Mr. Emelia Graham           2022-06-23                   71.0
# 7       No           Drake Hills           2022-06-23                   71.0
# 8       No         Kirk Mosciski           2022-06-23                   71.0
# 9       No         Verda Osinski           2022-06-23                   71.0
# 10      No     Lucius McCullough           2022-06-23                   71.0
# ...

# %%
def clean_df(df,cohort,scores):
    for score in scores:
        df.loc[(df['Cohort Name']==cohort)&(df[score].isna()),score]=df[df['Cohort Name']==cohort][score].mean()
    return df

# %%
df.isnull().sum()
# Out:
# at risk                   0
# Name                      0
# Career Week end date      0
# Days since graduation     0
# Cohort Name               0
# Outcome Category          0
# Outcome Status            0
# Track                     0
# Format                    0
# Campus                    0
# CV                        0
# Linkedin                  0
# Portfolio                 0
# Job ready pct             0
# Soft skills score        19
# Soft skills pct          19
# Assessment score          1
# Lab score                19
# Final project grade       0
# Final project pct         0
# dtype: int64

# %%
df=clean_df(df,'Cohort1',['Soft skills score','Soft skills pct','Assessment score','Lab score'])

# %%
df.isnull().sum()
# Out:
# at risk                   0
# Name                      0
# Career Week end date      0
# Days since graduation     0
# Cohort Name               0
# Outcome Category          0
# Outcome Status            0
# Track                     0
# Format                    0
# Campus                    0
# CV                        0
# Linkedin                  0
# Portfolio                 0
# Job ready pct             0
# Soft skills score        19
# Soft skills pct          19
# Assessment score          0
# Lab score                19
# Final project grade       0
# Final project pct         0
# dtype: int64

# %%
df['Final project pct']=df['Final project pct']*100
df['Final project pct']=df['Final project pct'].round(2)
df['Soft skills pct']=df['Soft skills pct']*100
df['Soft skills pct']=df['Soft skills pct'].round(2)
df['Job ready pct']=df['Job ready pct']*100
df['Job ready pct']=df['Job ready pct'].astype(int)

# %%
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0       No      Valentine Parker           2022-06-23                   71.0
# 1      Yes     Gregoria Veum III           2022-06-23                   71.0
# 2       No     Isai Turcotte DVM           2022-06-23                   71.0
# 3       No          Alex Mueller           2022-06-23                   71.0
# 4       No            Coy Kuphal           2022-06-23                   71.0
# 5       No           Janis Bayer           2022-06-23                   71.0
# 6       No     Mr. Emelia Graham           2022-06-23                   71.0
# 7       No           Drake Hills           2022-06-23                   71.0
# 8       No         Kirk Mosciski           2022-06-23                   71.0
# 9       No         Verda Osinski           2022-06-23                   71.0
# 10      No     Lucius McCullough           2022-06-23                   71.0
# ...

# %%
df.to_excel("Desktop/emplo_clean.xlsx")
